# %% [markdown]
# # Exercice partie 1
# ## Etape 1
# ### Chargement des jeux de données et visualisation

# %%
#exo 1 (2 en commentaire)
import pandas as pd
import numpy as np

EdStatsCountry = pd.read_csv("EdStatsCountry.csv") #ligne = pays (241, 32)
EdStatsCountry_Series = pd.read_csv("EdStatsCountry-Series.csv") #ligne = indicateurs code series pour un pays (613, 4), 0 doublons
EdStatsData = pd.read_csv("EdStatsData.csv") #ligne = indicateurs par pays (886930, 70), 0 doublons, 
EdStatsFootNote = pd.read_csv("EdStatsFootNote.csv") #ligne = indicateurs code series pour un pays, (643638, 5),  0 doublons
EdStatsSeries = pd.read_csv("EdStatsSeries.csv") #ligne = indicateur code series, (3665, 21), 0 doublons,

# %%
EdStatsCountry.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
# 3           AL    Albanian lek
# 4           AD            Euro
#
#                                        Special Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
EdStatsCountry_Series.head()
# Out:
#   CountryCode         SeriesCode  \
# 0         ABW        SP.POP.TOTL
# 1         ABW        SP.POP.GROW
# 2         AFG        SP.POP.GROW
# 3         AFG  NY.GDP.PCAP.PP.CD
# 4         AFG        SP.POP.TOTL
#
#                                          DESCRIPTION  Unnamed: 3
# 0  Data sources : United Nations World Population...         NaN
# 1  Data sources: United Nations World Population ...         NaN
# 2  Data sources: United Nations World Population ...         NaN
# 3                 Estimates are based on regression.         NaN
# 4  Data sources : United Nations World Population...         NaN

# %%
EdStatsData.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1970       1971       1972       1973       1974      1975  ...  2060  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 2        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# ...

# %%
EdStatsFootNote.head()
# Out:
#   CountryCode      SeriesCode    Year          DESCRIPTION  Unnamed: 4
# 0         ABW  SE.PRE.ENRL.FE  YR2001  Country estimation.         NaN
# 1         ABW  SE.TER.TCHR.FE  YR2005  Country estimation.         NaN
# 2         ABW  SE.PRE.TCHR.FE  YR2000  Country estimation.         NaN
# 3         ABW  SE.SEC.ENRL.GC  YR2004  Country estimation.         NaN
# 4         ABW     SE.PRE.TCHR  YR2006  Country estimation.         NaN

# %%
EdStatsSeries.head()
# Out:
#            Series Code       Topic  \
# 0  BAR.NOED.1519.FE.ZS  Attainment
# 1     BAR.NOED.1519.ZS  Attainment
# 2  BAR.NOED.15UP.FE.ZS  Attainment
# 3     BAR.NOED.15UP.ZS  Attainment
# 4  BAR.NOED.2024.FE.ZS  Attainment
#
#                                       Indicator Name  \
# 0  Barro-Lee: Percentage of female population age...
# 1  Barro-Lee: Percentage of population age 15-19 ...
# 2  Barro-Lee: Percentage of female population age...
# 3  Barro-Lee: Percentage of population age 15+ wi...
# 4  Barro-Lee: Percentage of female population age...
#
#                                     Short definition  \
# 0  Percentage of female population age 15-19 with...
# 1  Percentage of population age 15-19 with no edu...
# 2  Percentage of female population age 15+ with n...
# 3  Percentage of population age 15+ with no educa...
# 4  Percentage of female population age 20-24 with...
#
#                                      Long definition  Unit of measure  \
# ...

# %% [markdown]
# # Etapes 2
# ## Recherche des doublons

# %%
EdStatsCountry.duplicated("Country Code").sum()
# Out:
# np.int64(0)

# %%
EdStatsCountry.loc[EdStatsCountry["Country Code"].duplicated(keep=False),:]
# Out:
# Empty DataFrame
# Columns: [Country Code, Short Name, Table Name, Long Name, 2-alpha code, Currency Unit, Special Notes, Region, Income Group, WB-2 code, National accounts base year, National accounts reference year, SNA price valuation, Lending category, Other groups, System of National Accounts, Alternative conversion factor, PPP survey year, Balance of Payments Manual in use, External debt Reporting status, System of trade, Government Accounting concept, IMF data dissemination standard, Latest population census, Latest household survey, Source of most recent Income and expenditure data, Vital registration complete, Latest agricultural census, Latest industrial data, Latest trade data, Latest water withdrawal data, Unnamed: 31]
# Index: []
#
# [0 rows x 32 columns]

# %%
EdStatsCountry_Series.duplicated(["CountryCode", "SeriesCode"]).sum()
# Out:
# np.int64(0)

# %%
EdStatsCountry_Series.loc[EdStatsCountry_Series[["CountryCode", "SeriesCode"]].duplicated(keep=False),:]
# Out:
# Empty DataFrame
# Columns: [CountryCode, SeriesCode, DESCRIPTION, Unnamed: 3]
# Index: []

# %%
EdStatsData.duplicated(["Country Code", "Indicator Code"]).sum()
# Out:
# np.int64(0)

# %%
EdStatsData.loc[EdStatsData[["Country Code", "Indicator Code"]].duplicated(keep=False),:]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, Indicator Code, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2020, 2025, 2030, 2035, 2040, 2045, 2050, 2055, 2060, 2065, 2070, 2075, 2080, 2085, 2090, 2095, 2100, Unnamed: 69]
# Index: []
#
# [0 rows x 70 columns]

# %%
EdStatsFootNote.duplicated(["CountryCode", "SeriesCode"]).sum()
# Out:
# np.int64(570652)

# %%
EdStatsFootNote.loc[EdStatsFootNote[["CountryCode", "SeriesCode"]].duplicated(keep=False),:]
# Out:
#        CountryCode      SeriesCode    Year  \
# 0              ABW  SE.PRE.ENRL.FE  YR2001
# 1              ABW  SE.TER.TCHR.FE  YR2005
# 2              ABW  SE.PRE.TCHR.FE  YR2000
# 3              ABW  SE.SEC.ENRL.GC  YR2004
# 4              ABW     SE.PRE.TCHR  YR2006
# ...            ...             ...     ...
# 643632         ZWE     SH.DYN.MORT  YR2004
# 643633         ZWE     SH.DYN.MORT  YR2007
# 643634         ZWE     SH.DYN.MORT  YR2014
# 643635         ZWE     SH.DYN.MORT  YR2015
# 643636         ZWE     SH.DYN.MORT  YR2017
#
#                                    DESCRIPTION  Unnamed: 4
# 0                          Country estimation.         NaN
# 1                          Country estimation.         NaN
# 2                          Country estimation.         NaN
# 3                          Country estimation.         NaN
# 4                          Country estimation.         NaN
# ...                                        ...         ...
# ...

# %%
EdStatsFootNote.loc[EdStatsFootNote[["CountryCode", "SeriesCode", "Year", "DESCRIPTION"]].duplicated(keep=False),:]
# Out:
# Empty DataFrame
# Columns: [CountryCode, SeriesCode, Year, DESCRIPTION, Unnamed: 4]
# Index: []

# %%
EdStatsSeries.duplicated("Series Code").sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Suppression des colonnes non utilisables

# %%
EdStatsCountry.isna().mean()
# Out:
# Country Code                                         0.000000
# Short Name                                           0.000000
# Table Name                                           0.000000
# Long Name                                            0.000000
# 2-alpha code                                         0.012448
# Currency Unit                                        0.107884
# Special Notes                                        0.398340
# Region                                               0.112033
# Income Group                                         0.112033
# WB-2 code                                            0.004149
# National accounts base year                          0.149378
# National accounts reference year                     0.867220
# SNA price valuation                                  0.182573
# Lending category                                     0.402490
# Other groups                                         0.759336
# ...

# %%
EdStatsCountry = EdStatsCountry.drop("Unnamed: 31", axis = 1)

# %%
EdStatsCountry_Series.isna().mean()
# Out:
# CountryCode    0.0
# SeriesCode     0.0
# DESCRIPTION    0.0
# Unnamed: 3     1.0
# dtype: float64

# %%
EdStatsCountry_Series = EdStatsCountry_Series.drop("Unnamed: 3", axis = 1)

# %%
EdStatsData.isna().mean()
# Out:
# Country Name      0.000000
# Country Code      0.000000
# Indicator Name    0.000000
# Indicator Code    0.000000
# 1970              0.918496
#                     ...
# 2085              0.942007
# 2090              0.942007
# 2095              0.942007
# 2100              0.942007
# Unnamed: 69       1.000000
# Length: 70, dtype: float64

# %%
EdStatsData = EdStatsData.drop("Unnamed: 69", axis = 1)

# %%
EdStatsFootNote.isna().mean()
# Out:
# CountryCode    0.0
# SeriesCode     0.0
# Year           0.0
# DESCRIPTION    0.0
# Unnamed: 4     1.0
# dtype: float64

# %%
EdStatsFootNote = EdStatsFootNote.drop("Unnamed: 4", axis = 1)

# %%
EdStatsSeries.isna().mean()
# Out:
# Series Code                            0.000000
# Topic                                  0.000000
# Indicator Name                         0.000000
# Short definition                       0.411733
# Long definition                        0.000000
# Unit of measure                        1.000000
# Periodicity                            0.972988
# Base Period                            0.914325
# Other notes                            0.849386
# Aggregation method                     0.987176
# Limitations and exceptions             0.996180
# Notes from original source             1.000000
# General comments                       0.996180
# Source                                 0.000000
# Statistical concept and methodology    0.993724
# Development relevance                  0.999181
# Related source links                   0.941337
# Other web links                        1.000000
# Related indicators                     1.000000
# License Type                           1.000000
# ...

# %%
EdStatsSeries = EdStatsSeries.drop(["Unit of measure", "Notes from original source", "Other web links", "Related indicators", "License Type", "Unnamed: 20"], axis = 1)

# %% [markdown]
# # Description des colonnes numeriques

# %%
EdStatsCountry.describe()
# Out:
#        National accounts reference year  Latest industrial data  \
# count                          32.00000              107.000000
# mean                         2001.53125             2008.102804
# std                             5.24856                2.616834
# min                          1987.00000             2000.000000
# 25%                          1996.75000             2007.500000
# 50%                          2002.00000             2009.000000
# 75%                          2005.00000             2010.000000
# max                          2012.00000             2010.000000
#
#        Latest trade data
# count         185.000000
# mean         2010.994595
# std             2.569675
# min          1995.000000
# 25%          2011.000000
# 50%          2012.000000
# 75%          2012.000000
# max          2012.000000

# %%
EdStatsCountry_Series.describe()
# Out:
#        CountryCode   SeriesCode  \
# count          613          613
# unique         211           21
# top            GEO  SP.POP.TOTL
# freq            18          211
#
#                                               DESCRIPTION
# count                                                 613
# unique                                                 97
# top     Data sources : United Nations World Population...
# freq                                                  154

# %%
EdStatsData.describe()
# Out:
#                1970          1971          1972          1973          1974  \
# count  7.228800e+04  3.553700e+04  3.561900e+04  3.554500e+04  3.573000e+04
# mean   1.974772e+09  4.253638e+09  4.592365e+09  5.105006e+09  5.401493e+09
# std    1.211687e+11  1.804814e+11  1.914083e+11  2.059170e+11  2.112150e+11
# min   -1.435564e+00 -1.594625e+00 -3.056522e+00 -4.032582e+00 -4.213563e+00
# 25%    8.900000e-01  8.853210e+00  9.240920e+00  9.595200e+00  9.861595e+00
# 50%    6.317724e+00  6.316240e+01  6.655139e+01  6.969595e+01  7.087760e+01
# 75%    6.251250e+01  5.655200e+04  5.863650e+04  6.202900e+04  6.383675e+04
# max    1.903929e+13  1.986457e+13  2.100916e+13  2.238367e+13  2.282991e+13
#
#                1975          1976          1977          1978          1979  \
# count  8.730600e+04  3.748300e+04  3.757400e+04  3.757600e+04  3.680900e+04
# mean   2.314288e+09  5.731808e+09  6.124437e+09  6.671489e+09  7.436724e+09
# ...

# %%
EdStatsFootNote.describe()
# Out:
#        CountryCode   SeriesCode    Year   DESCRIPTION
# count       643638       643638  643638        643638
# unique         239         1558      56          9102
# top            LIC  SH.DYN.MORT  YR2004  Country Data
# freq          7320         9226   27128        191188

# %%
EdStatsSeries.describe()
# Out:
#                         Series Code              Topic  \
# count                          3665               3665
# unique                         3665                 37
# top     XGDP.56.FSGOV.FDINSTADM.FFD  Learning Outcomes
# freq                              1               1046
#
#                                            Indicator Name  \
# count                                                3665
# unique                                               3665
# top     Government expenditure in tertiary institution...
# freq                                                    1
#
#                                          Short definition  \
# count                                                2156
# unique                                               1169
# top     Data Interpretation: 1=Latent; 2=Emerging; 3=E...
# freq                                                  215
#
#                                           Long definition Periodicity  \
# ...

# %% [markdown]
# # Description des colonnes categorielles

# %%
EdStatsCountry["Currency Unit"].value_counts()
EdStatsCountry["Region"].value_counts()
EdStatsCountry["Income Group"].value_counts()
EdStatsCountry["Other groups"].value_counts()
EdStatsCountry["System of National Accounts"].value_counts()
EdStatsCountry["System of trade"].value_counts()
EdStatsCountry["Government Accounting concept"].value_counts()
EdStatsCountry["IMF data dissemination standard"].value_counts()
# Out:
# IMF data dissemination standard
# General Data Dissemination System (GDDS)      110
# Special Data Dissemination Standard (SDDS)     71
# Name: count, dtype: int64

# %%
EdStatsCountry_Series["SeriesCode"].value_counts()
EdStatsCountry_Series["DESCRIPTION"].value_counts()
# Out:
# DESCRIPTION
# Data sources : United Nations World Population Prospects                                              154
# Data sources: United Nations World Population Prospects                                               137
# Estimates are based on regression.                                                                     84
# Data sources : Eurostat                                                                                54
# Derived using ratio of age group from WPP and World Bank population.                                   24
#                                                                                                      ...
# Data sources : U.S. Census Bureau, United Nations Population and Vital Statistics Report                1
# Data sources: General Statistics Office of Vietnam                                                      1
# Data sources : General Statistics Office of Vietnam                                                     1
# ...

# %%
EdStatsData["Indicator Name"].value_counts()
EdStatsData["Indicator Code"].value_counts()
# Out:
# Indicator Code
# SE.ADT.1524.LT.MA.ZS    242
# PRJ.POP.ALL.4.FE        242
# PRJ.POP.ALL.NED.MF      242
# PRJ.POP.ALL.NED.MA      242
# PRJ.POP.ALL.NED.FE      242
#                        ...
# SE.PRM.TENR.FE          242
# SE.PRM.TENR             242
# UIS.NERA.2.M            242
# UIS.NERA.2.GPI          242
# UIS.NERA.2.F            242
# Name: count, Length: 3665, dtype: int64

# %%
EdStatsFootNote["SeriesCode"].value_counts()
EdStatsFootNote["DESCRIPTION"].value_counts()
# Out:
# DESCRIPTION
# Country Data                                      191188
# UNESCO Institute for Statistics (UIS) estimate    171527
# Estimated                                         117155
# UIS Estimation                                     31395
# Country estimation.                                26308
#                                                    ...
# Plausible bound is 12.5-16.1                           1
# Uncertainty bound is 102.1 - 124.7                     1
# Uncertainty bound is 100.9 - 118.9                     1
# Uncertainty bound is 99.6 - 117.2                      1
# Uncertainty bound is 127.1 - 148.2                     1
# Name: count, Length: 9102, dtype: int64

# %%
EdStatsSeries["Topic"].value_counts()
EdStatsSeries["Short definition"].value_counts()
EdStatsSeries["Long definition"].value_counts()
EdStatsSeries["Source"].value_counts()
# Out:
# Source
# UNESCO Institute for Statistics                                                                                                                                                                                                                                                                                                                                                                                                                                                             1269
# Early Grade Reading Assessment (EGRA): https://www.eddataglobal.org/reading/                                                                                                                                                                                                                                                                                                                                                                                                                 403
# ...

# %%
#etape 3
EdStatsCountry.head(20)
# Out:
#    Country Code            Short Name            Table Name  \
# 0           ABW                 Aruba                 Aruba
# 1           AFG           Afghanistan           Afghanistan
# 2           AGO                Angola                Angola
# 3           ALB               Albania               Albania
# 4           AND               Andorra               Andorra
# 5           ARB            Arab World            Arab World
# 6           ARE  United Arab Emirates  United Arab Emirates
# 7           ARG             Argentina             Argentina
# 8           ARM               Armenia               Armenia
# 9           ASM        American Samoa        American Samoa
# 10          ATG   Antigua and Barbuda   Antigua and Barbuda
# 11          AUS             Australia             Australia
# 12          AUT               Austria               Austria
# 13          AZE            Azerbaijan            Azerbaijan
# 14          BDI               Burundi               Burundi
# ...

# %% [markdown]
# # Recherches des faux pays
# ## On remarque dans le dataframe du dessus que certains pays n'ont pas de monnaie ni de region
# ### Recherche des pays qui n'ont pas de monnaie

# %%
dfFauxPays = EdStatsCountry.loc[EdStatsCountry["Currency Unit"].isna(),]
display(dfFauxPays)
# Out:
#     Country Code                                      Short Name  \
# 5            ARB                                      Arab World
# 57           EAP           East Asia & Pacific (developing only)
# 58           EAS         East Asia & Pacific (all income levels)
# 59           ECA         Europe & Central Asia (developing only)
# 60           ECS       Europe & Central Asia (all income levels)
# 63           EMU                                       Euro area
# 68           EUU                                  European Union
# 89           HIC                                     High income
# 92           HPC          Heavily indebted poor countries (HIPC)
# 116          LAC     Latin America & Caribbean (developing only)
# 122          LCN   Latin America & Caribbean (all income levels)
# 123          LDC    Least developed countries: UN classification
# 124          LIC                                      Low income
# ...

# %% [markdown]
# # Suppression des lignes du df Country

# %%
lignes_a_supprimer = dfFauxPays.index
EdStatsCountry = EdStatsCountry.drop(lignes_a_supprimer, axis=0)
EdStatsCountry.tail(20)
# Out:
#     Country Code                      Short Name  \
# 219          TUN                         Tunisia
# 220          TUR                          Turkey
# 221          TUV                          Tuvalu
# 222          TZA                        Tanzania
# 223          UGA                          Uganda
# 224          UKR                         Ukraine
# 226          URY                         Uruguay
# 227          USA                   United States
# 228          UZB                      Uzbekistan
# 229          VCT  St. Vincent and the Grenadines
# 230          VEN                       Venezuela
# 231          VIR                  Virgin Islands
# 232          VNM                         Vietnam
# 233          VUT                         Vanuatu
# 235          WSM                           Samoa
# 236          XKX                          Kosovo
# 237          YEM                           Yemen
# 238          ZAF                    South Africa
# ...

# %% [markdown]
# # Suppression des lignes correspondantes dans les autres df via la methode 1

# %%
listeFauxPays = dfFauxPays["Country Code"].tolist()
EdStatsCountry_SeriesNew = EdStatsCountry_Series.loc[~EdStatsCountry_Series["CountryCode"].isin(listeFauxPays),] #aucune ligne supprimée
EdStatsDataNew = EdStatsData.loc[~EdStatsData["Country Code"].isin(listeFauxPays),] 
EdStatsFootNoteNew = EdStatsFootNote.loc[~EdStatsFootNote["CountryCode"].isin(listeFauxPays),] 
EdStatsFootNoteNew.shape
# Out:
# (517338, 4)

# %% [markdown]
# # Suppression des lignes correspondantes dans les autres df via la methode 2

# %%
colonnePays = EdStatsCountry["Country Code"]
EdStatsCountry_SeriesNew2 = pd.merge(colonnePays, EdStatsCountry_Series, left_on = "Country Code", right_on = "CountryCode", how = "inner")
EdStatsDataNew2 = pd.merge(colonnePays, EdStatsData, on = "Country Code", how = "inner") 
EdStatsFootNoteNew2 = pd.merge(colonnePays, EdStatsFootNote, left_on = "Country Code", right_on = "CountryCode", how = "inner") 
EdStatsFootNoteNew2.shape
# Out:
# (516347, 5)

# %% [markdown]
# # Methode ChatGPT

# %%
# Standardisation des Country Codes dans tous les DataFrames
def clean_country_code(df, col_name):
    df[col_name] = df[col_name].astype(str).str.strip()
    df = df[df[col_name].notna()]  # Suppression des valeurs NaN
    return df

# Nettoyage de chaque DataFrame
EdStatsData = clean_country_code(EdStatsData, "Country Code")
EdStatsFootNote = clean_country_code(EdStatsFootNote, "CountryCode")
EdStatsCountry_Series = clean_country_code(EdStatsCountry_Series, "CountryCode")
EdStatsCountry = clean_country_code(EdStatsCountry, "Country Code")

# Supposons que dfFauxPays a été généré à partir d'une analyse préalable
# (par exemple : noms suspects, régions, agrégats, etc.)

# Création de la liste des codes à exclure
listeFauxPays = dfFauxPays["Country Code"].astype(str).str.strip().tolist()

# Nettoyage du DataFrame des pays
EdStatsCountryClean = EdStatsCountry[~EdStatsCountry["Country Code"].isin(listeFauxPays)].drop_duplicates(subset="Country Code")

# Méthode 1
EdStatsDataNew_m1 = EdStatsData[~EdStatsData["Country Code"].isin(listeFauxPays)].copy()
EdStatsFootNoteNew_m1 = EdStatsFootNote[~EdStatsFootNote["CountryCode"].isin(listeFauxPays)].copy()
EdStatsCountry_SeriesNew_m1 = EdStatsCountry_Series[~EdStatsCountry_Series["CountryCode"].isin(listeFauxPays)].copy()

# Extraire les pays valides
colonnePays = EdStatsCountryClean["Country Code"].drop_duplicates()

# Méthode 2 avec merge
EdStatsDataNew_m2 = EdStatsData.merge(colonnePays, on="Country Code", how="inner")
EdStatsFootNoteNew_m2 = EdStatsFootNote.merge(colonnePays, left_on="CountryCode", right_on="Country Code", how="inner")
EdStatsCountry_SeriesNew_m2 = EdStatsCountry_Series.merge(colonnePays, left_on="CountryCode", right_on="Country Code", how="inner")

#Verification
print("Méthode 1 - FootNote:", EdStatsFootNoteNew_m1.shape[0])
print("Méthode 2 - FootNote:", EdStatsFootNoteNew_m2.shape[0])

# Identifier les différences si elles persistent
diffFootNote = pd.concat([EdStatsFootNoteNew_m1, EdStatsFootNoteNew_m2]).drop_duplicates(keep=False)
print("Différences FootNote entre les deux méthodes :", diffFootNote.shape)
# Out:
# Méthode 1 - FootNote: 517338
# Méthode 2 - FootNote: 516347
# Différences FootNote entre les deux méthodes : (1033685, 5)

# %% [markdown]
# # Exercice partie 2
# ## Etape 1
# ### La colonne Topic du dataFrame EdStatsSeries semble être la colonne qui décrit la catégorie métier à laquelle appartient chaque indicateur.

# %%
EdStatsSeries["Topic"].unique()
# Out:
# array(['Attainment', 'Education Equality',
#        'Infrastructure: Communications', 'Learning Outcomes',
#        'Economic Policy & Debt: National accounts: US$ at current prices: Aggregate indicators',
#        'Economic Policy & Debt: National accounts: US$ at constant 2010 prices: Aggregate indicators',
#        'Economic Policy & Debt: Purchasing power parity',
#        'Economic Policy & Debt: National accounts: Atlas GNI & GNI per capita',
#        'Teachers', 'Education Management Information Systems (SABER)',
#        'Early Child Development (SABER)',
#        'Engaging the Private Sector (SABER)',
#        'School Health and School Feeding (SABER)',
#        'School Autonomy and Accountability (SABER)',
#        'School Finance (SABER)', 'Student Assessment (SABER)',
#        'Teachers (SABER)', 'Tertiary Education (SABER)',
#        'Workforce Development (SABER)', 'Literacy', 'Background',
#        'Primary', 'Secondary', 'Tertiary', 'Early Childhood Education',
# ...

# %% [markdown]
# # Nous notons les grandes familles education, santé, protection sociale, economie
# ### les topic de type éducation sont directement liés à notre recherche, economie peut donner des indication sur le pouvoir d'achat pour se payer les formations, protection sociale donne des indication débouchés pour les etudiants diplomés, pour la santé nous pouvons nous passer des données sur la mortalité ou sur les risques on va donc supprimer les lignes correspondantes

# %%
EdStatsSeries.shape
# Out:
# (3665, 15)

# %%
dfIndicateurInutile = EdStatsSeries.loc[EdStatsSeries["Topic"].isin(["Health: Risk factors", "Health: Mortality"]),:]
EdStatsSeriesNew = EdStatsSeries.drop(dfIndicateurInutile.index, axis = 0)
EdStatsSeriesNew.shape
# Out:
# (3663, 15)

# %% [markdown]
# # Calcul du nombre d'indicateurs restants
# ## Regardons s'il y a plusieurs fois le meme Series code dans le DataFrame series, si ce n'est pas le cas le nombre d'indicateur correspondra aux nombre de lignes 3663

# %%
EdStatsSeriesNew.duplicated(["Series Code"]).sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Filtrez l’ensemble des jeux de données pour ne garder que les indicateurs sélectionnés.

# %%
listeIndicateurInutile = dfIndicateurInutile["Series Code"].tolist()
EdStatsCountry_SeriesNew = EdStatsCountry_SeriesNew.loc[~EdStatsCountry_SeriesNew["SeriesCode"].isin(listeIndicateurInutile),] #aucune ligne supprimée
EdStatsDataNew = EdStatsDataNew.loc[~EdStatsDataNew["Indicator Code"].isin(listeIndicateurInutile),] 
EdStatsFootNoteNew = EdStatsFootNoteNew.loc[~EdStatsFootNoteNew["SeriesCode"].isin(listeIndicateurInutile),] 
EdStatsFootNoteNew.shape
# Out:
# (505122, 4)

# %% [markdown]
# # Dans le fichier Data, interprétez les colonnes représentant les années.

# %%
EdStatsDataNew.head()
# Out:
#       Country Name Country Code  \
# 91625  Afghanistan          AFG
# 91626  Afghanistan          AFG
# 91627  Afghanistan          AFG
# 91628  Afghanistan          AFG
# 91629  Afghanistan          AFG
#
#                                           Indicator Name  Indicator Code  \
# 91625  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 91626  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 91627  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 91628  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 91629  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#        1970  1971  1972  1973      1974  1975  ...  2055  2060  2065  2070  \
# 91625   NaN   NaN   NaN   NaN   7.05911   NaN  ...   NaN   NaN   NaN   NaN
# 91626   NaN   NaN   NaN   NaN   2.53138   NaN  ...   NaN   NaN   NaN   NaN
# 91627   NaN   NaN   NaN   NaN   0.22154   NaN  ...   NaN   NaN   NaN   NaN
# ...

# %% [markdown]
# ## Pourquoi avons-nous des valeurs d’indicateur pour des années futures ?
# ### Ce semble être des projections des valeurs des indicateurs pour le futur
# ## Sur la base de votre compréhension de la problématique métier, filtrez les années en conséquence.
# ### On peut considérer le projet à horizon 5 ans donc toutes les estimations posts 2030 ne sont pas necessaires

# %%
années_utiles = [col for col in EdStatsDataNew.columns if col.isdigit() and int(col) <= 2030]
EdStatsDataNewA = EdStatsDataNew[['Country Name', 'Country Code','Indicator Name', 'Indicator Code'] + années_utiles]

# %%
EdStatsDataNewA.head()
# Out:
#       Country Name Country Code  \
# 91625  Afghanistan          AFG
# 91626  Afghanistan          AFG
# 91627  Afghanistan          AFG
# 91628  Afghanistan          AFG
# 91629  Afghanistan          AFG
#
#                                           Indicator Name  Indicator Code  \
# 91625  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 91626  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 91627  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 91628  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 91629  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#        1970  1971  1972  1973      1974  1975  ...  2011  2012       2013  \
# 91625   NaN   NaN   NaN   NaN   7.05911   NaN  ...   NaN   NaN  47.436790
# 91626   NaN   NaN   NaN   NaN   2.53138   NaN  ...   NaN   NaN  34.073261
# 91627   NaN   NaN   NaN   NaN   0.22154   NaN  ...   NaN   NaN   0.567060
# ...

# %% [markdown]
# # Etape 2
# ## Pour chaque année, calculez la proportion d’indicateurs avec des valeurs renseignées (c’est-à-dire, non manquantes).

# %%
EdStatsDataNewA.notna().mean().sort_values()
# Out:
# 2017               0.000181
# 2016               0.019413
# 1973               0.039492
# 1974               0.039692
# 1972               0.039740
# 1971               0.039863
# 1989               0.040803
# 1979               0.040810
# 1982               0.041525
# 1976               0.041759
# 1978               0.041839
# 1977               0.041846
# 1988               0.042103
# 1987               0.042235
# 1983               0.042620
# 1984               0.042746
# 1981               0.043133
# 1986               0.043166
# 2025               0.064620
# 2020               0.064620
# 2030               0.064620
# 1997               0.083561
# 1970               0.086492
# 1991               0.086828
# 1992               0.087901
# 1993               0.087998
# 1996               0.088733
# 1994               0.089705
# 1998               0.096593
# 1975               0.104788
# 1980               0.106803
# 1985               0.107616
# 2014               0.132719
# ...

# %% [markdown]
# ## Pour chaque indicateur, calculez la proportion d’années avec des valeurs renseignées.

# %%
# Calculer le taux de remplissage ligne par ligne, sur les colonnes années uniquement
EdStatsDataNewA["TauxRemplissage"] = EdStatsDataNewA[années_utiles].notna().mean(axis=1)

# Regrouper par 'Indicator Code' et calculer le taux moyen de remplissage par indicateur
tauxParIndicateur = EdStatsDataNewA.groupby("Indicator Code")["TauxRemplissage"].mean().sort_values()
display(tauxParIndicateur)
# Out:
# C:\Users\livit\AppData\Local\Temp\ipykernel_19860\2905741757.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EdStatsDataNewA["TauxRemplissage"] = EdStatsDataNewA[années_utiles].notna().mean(axis=1)
# Indicator Code
# LO.EGRA.READ.0.AFA.3GRD      0.000091
# LO.EGRA.READ.0.BOM.2GRD      0.000091
# LO.EGRA.READ.ICI.ADV.2GRD    0.000091
# LO.EGRA.READ.IND.ADV.3GRD    0.000091
# LO.EGRA.READ.0.CHI.2GRD      0.000091
#                                ...
# UIS.THDUR.0                  0.865196
# SE.PRM.AGES                  0.869826
# SE.PRM.DURS                  0.869826
# SP.POP.GROW                  0.906227
# SP.POP.TOTL                  0.906772
# Name: TauxRemplissage, Length: 3663, dtype: float64

# %% [markdown]
# # Sur la base des opérations précédentes, réduisez le nombre d’années et d’indicateurs pour garder celles et ceux qui sont les plus riches en données (et donc les plus utilisables pour la suite).
# ## Identifiez les indicateurs particulièrement riches en données en calculant un dataframe contenant par indicateur et par année, le nombre de pays avec une valeur renseignée.
# ### On va changer le format du DataFrame en lignes avec melt puis filtrer sur les valeurs non nulles pour faire un décompte des pays par indicateur et par années

# %%
# 1. Transformation au format long (année = variable, value = valeur)
EdStatsDataMelt = EdStatsDataNewA.melt(
    id_vars=["Country Name", "Country Code", "Indicator Code", "Indicator Name", "TauxRemplissage"],
    var_name="Year",
    value_name="Value"
)

# 2. Garder uniquement les lignes avec une valeur renseignée
EdStatsDataMelt = EdStatsDataMelt.loc[EdStatsDataMelt["Value"].notna()]

# 3. Grouper par indicateur et année, et compter le nombre de pays
EdStatsDataP2E2 = EdStatsDataMelt.groupby(["Indicator Code", "Year"])["Country Code"].nunique().reset_index()

EdStatsDataMelt.head()
# Out:
#     Country Name Country Code        Indicator Code  \
# 149  Afghanistan          AFG  BAR.PRM.SCHL.15UP.FE
# 150  Afghanistan          AFG     BAR.PRM.SCHL.15UP
# 151  Afghanistan          AFG  BAR.PRM.SCHL.1519.FE
# 152  Afghanistan          AFG     BAR.PRM.SCHL.1519
# 153  Afghanistan          AFG  BAR.PRM.SCHL.2024.FE
#
#                                         Indicator Name  TauxRemplissage  Year  \
# 149  Barro-Lee: Average years of primary schooling,...         0.176471  1970
# 150  Barro-Lee: Average years of primary schooling,...         0.176471  1970
# 151  Barro-Lee: Average years of primary schooling,...         0.176471  1970
# 152  Barro-Lee: Average years of primary schooling,...         0.176471  1970
# 153  Barro-Lee: Average years of primary schooling,...         0.176471  1970
#
#      Value
# 149   0.11
# 150   0.45
# 151   0.32
# 152   0.90
# 153   0.22

# %% [markdown]
# ## Triez ce dataframe par ordre décroissant de nombre de pays avec une valeur renseignée, afin d’obtenir les indicateurs les plus riches en données dans l’ensemble.

# %%
EdStatsDataP2E2.sort_values(by="Country Code", ascending=False)
# Out:
#                   Indicator Code  Year  Country Code
# 24341                SP.POP.TOTL  2007           215
# 24342                SP.POP.TOTL  2008           215
# 24343                SP.POP.TOTL  2009           215
# 24344                SP.POP.TOTL  2010           215
# 24345                SP.POP.TOTL  2011           215
# ...                          ...   ...           ...
# 7641   LO.EGRA.READ.CHC.ADV.4GRD  2012             1
# 7640   LO.EGRA.READ.CHC.ADV.4GRD  2011             1
# 7639   LO.EGRA.READ.CHC.ADV.4GRD  2010             1
# 7606     LO.EGRA.READ.0.KIS.2GRD  2014             1
# 7605     LO.EGRA.READ.0.KII.2GRD  2014             1
#
# [50971 rows x 3 columns]

# %% [markdown]
# ## Aidez-vous de ce dataframe pour sélectionner parmi les indicateurs les plus riches, une quinzaine qui font sens par rapport à la problématique métier.
# ### prenons les 15 premiers et allons voir a quoi ils correspondent

# %%
# 1. Grouper par indicateur, et trouver le nombre maximal de pays renseignés une année
EdStatsDataIndicateur = EdStatsDataP2E2.groupby("Indicator Code")["Country Code"].max()

# 2. Trier dans l’ordre décroissant
EdStatsDataIndicateur = EdStatsDataIndicateur.sort_values(ascending=False)

EdStatsDataIndicateur.head(21)
# Out:
# Indicator Code
# SP.POP.GROW          215
# SP.POP.TOTL          215
# SE.SEC.DURS.LO       207
# SE.SEC.DURS.UP       207
# SE.SEC.AGES          207
# SE.PRM.AGES          207
# SE.PRM.DURS          207
# UIS.THDUR.0          207
# UIS.THAGE.0          206
# IT.NET.USER.P2       206
# UIS.THAGE.3.A.GPV    206
# NY.GDP.MKTP.CD       205
# NY.GDP.PCAP.CD       205
# SE.SEC.DURS          204
# NY.GDP.MKTP.KD       202
# NY.GDP.PCAP.KD       202
# NY.GNP.MKTP.CD       196
# SP.SEC.UTOT.IN       196
# UIS.OE.56.40510      196
# SP.SEC.UTOT.FE.IN    195
# SP.SEC.LTOT.IN       195
# Name: Country Code, dtype: int64

# %%
pd.set_option('display.max_colwidth', None)
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "SP.POP.TOTL", "Indicator Name"]
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "SP.POP.GROW", "Indicator Name"]
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "SE.SEC.DURS.LO", "Indicator Name"]
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "SE.SEC.AGES", "Indicator Name"]
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "UIS.THDUR.0", "Indicator Name"]
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "IT.NET.USER.P2", "Indicator Name"]
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "UIS.THAGE.3.A.GPV", "Indicator Name"]
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "NY.GDP.MKTP.CD", "Indicator Name"] # à enlever
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "NY.GDP.PCAP.CD", "Indicator Name"] # à enlever
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "SE.SEC.DURS", "Indicator Name"] 
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "NY.GDP.MKTP.KD", "Indicator Name"] # à enlever 
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "SP.SEC.UTOT.IN", "Indicator Name"]
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "UIS.OE.56.40510", "Indicator Name"] # à enlever 
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "SP.SEC.UTOT.FE.IN", "Indicator Name"]
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "SP.SEC.LTOT.IN", "Indicator Name"]
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "SE.SEC.DURS.UP", "Indicator Name"]
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "SE.PRM.AGES", "Indicator Name"]
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "SE.PRM.DURS", "Indicator Name"]
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "UIS.THAGE.0", "Indicator Name"]
# Out:
# 93308     Official entrance age to pre-primary education (years)
# 96973     Official entrance age to pre-primary education (years)
# 100638    Official entrance age to pre-primary education (years)
# 104303    Official entrance age to pre-primary education (years)
# 107968    Official entrance age to pre-primary education (years)
#                                    ...
# 870288    Official entrance age to pre-primary education (years)
# 873953    Official entrance age to pre-primary education (years)
# 877618    Official entrance age to pre-primary education (years)
# 881283    Official entrance age to pre-primary education (years)
# 884948    Official entrance age to pre-primary education (years)
# Name: Indicator Name, Length: 216, dtype: object

# %% [markdown]
# ### Nous enlevons les indicateurs en rapport avec le PIB et gardons les autres

# %% [markdown]
# # Etape 3
# ## Filtrez votre dataframe Data pour ne garder que les indicateurs, pays et années que vous avez jugé pertinents sur la base de vos analyses précédentes

# %%
indicateurs_utiles = ["SP.POP.TOTL", "SP.POP.GROW", "SE.SEC.DURS.LO", "SE.SEC.DURS.UP", "SE.SEC.AGES", "SE.PRM.AGES", "SE.PRM.DURS", "UIS.THDUR.0", "UIS.THAGE.0", "IT.NET.USER.P2", "UIS.THAGE.3.A.GPV", "SE.SEC.DURS", "SP.SEC.UTOT.IN", "SP.SEC.UTOT.FE.IN", "SP.SEC.LTOT.IN"]
EdStatsDataFiltre = EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"].isin(indicateurs_utiles)]
EdStatsDataFiltre.head()
# Out:
#       Country Name Country Code  \
# 93000  Afghanistan          AFG
# 93306  Afghanistan          AFG
# 93308  Afghanistan          AFG
# 93309  Afghanistan          AFG
# 93310  Afghanistan          AFG
#
#                                                    Indicator Name  \
# 93000                             Internet users (per 100 people)
# 93306  Official entrance age to lower secondary education (years)
# 93308      Official entrance age to pre-primary education (years)
# 93309          Official entrance age to primary education (years)
# 93310  Official entrance age to upper secondary education (years)
#
#           Indicator Code  1970  1971  1972  1973  1974  1975  ...       2012  \
# 93000     IT.NET.USER.P2   NaN   NaN   NaN   NaN   NaN   NaN  ...   5.454545
# 93306        SE.SEC.AGES  13.0  13.0  13.0  13.0  13.0  12.0  ...  13.000000
# 93308        UIS.THAGE.0   3.0   3.0   3.0   3.0   3.0   3.0  ...   3.000000
# ...

# %% [markdown]
# ## Agrégez ce dataframe pour en construire un nouveau : chaque ligne doit correspondre à un pays et chaque colonne doit correspondre à un indicateur.

# %%
# Calculer la moyenne des années sélectionnées pour chaque ligne
EdStatsDataFiltre["Moyenne"] = EdStatsDataFiltre[années_utiles].mean(axis=1)

EdStatsDataPivot = EdStatsDataFiltre.pivot_table(index="Country Name", columns="Indicator Code", values="Moyenne")
EdStatsDataPivot.head()
# Out:
# C:\Users\livit\AppData\Local\Temp\ipykernel_19860\488255602.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EdStatsDataFiltre["Moyenne"] = EdStatsDataFiltre[années_utiles].mean(axis=1)
# Indicator Code  IT.NET.USER.P2  SE.PRM.AGES  SE.PRM.DURS  SE.SEC.AGES  \
# Country Name
# Afghanistan           3.354972     6.891304     6.000000    12.891304
# Albania              21.555784     6.000000     4.170213    10.170213
# Algeria               9.692493     6.000000     5.847826    11.847826
# American Samoa        0.000000     6.000000     6.944444    13.636364
# Andorra              48.592382     6.000000     5.425532    11.404255
#
# Indicator Code  SE.SEC.DURS  SE.SEC.DURS.LO  SE.SEC.DURS.UP  SP.POP.GROW  \
# Country Name
# ...

# %% [markdown]
# # Exercice Partie 3
# ## Etape 1
# ### Calculez une matrice de corrélation entre l’ensemble des indicateurs en utilisant la méthode de Pearson puis de Spearman (consultez le lien dans les ressources ci-dessous si besoin)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import scipy.stats as st

# %%
matricePearson = EdStatsDataPivot.corr()
matricePearson.head()

plt.figure(figsize=(10, 8))
sns.heatmap(matricePearson, annot=True, cmap="coolwarm", center=0)
plt.title("Matrice de corrélation des indicateurs (Pearson)")
plt.show()

# %%
matriceSpearman = EdStatsDataPivot.corr(method='spearman')
matriceSpearman.head()

plt.figure(figsize=(10, 8))
sns.heatmap(matriceSpearman, annot=True, cmap="coolwarm", center=0)
plt.title("Matrice de corrélation des indicateurs (Spearman)")
plt.show()

# %% [markdown]
# ## Supprimez les indicateurs excessivement corrélés (donc redondants).
# ### Les matrices de corrélation sur les indicateurs nous permettre d'identifier les variables ayant une forte correlation linéaire en rouge (les autres types de corrélation ne sont pas mesurés)
# ### On regarde le nom complet des indicateurs pour estimer lesquels sont plus pertinant a garder entre ceux ayant une forte corrélation

# %%
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "SP.SEC.LTOT.IN", "Indicator Name"]
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "SP.SEC.UTOT.FE.IN", "Indicator Name"]
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "SP.SEC.UTOT.IN", "Indicator Name"] # le plus pertinent
# Out:
# 93957     Population of the official age for upper secondary education, both sexes (number)
# 97622     Population of the official age for upper secondary education, both sexes (number)
# 101287    Population of the official age for upper secondary education, both sexes (number)
# 104952    Population of the official age for upper secondary education, both sexes (number)
# 108617    Population of the official age for upper secondary education, both sexes (number)
#                                                 ...
# 870937    Population of the official age for upper secondary education, both sexes (number)
# 874602    Population of the official age for upper secondary education, both sexes (number)
# 878267    Population of the official age for upper secondary education, both sexes (number)
# 881932    Population of the official age for upper secondary education, both sexes (number)
# 885597    Population of the official age for upper secondary education, both sexes (number)
# ...

# %%
EdStatsDataPivotP3E1 = EdStatsDataPivot.drop(["SP.SEC.LTOT.IN", "SP.POP.TOTL", "SP.SEC.UTOT.FE.IN"], axis = 1)

# %%
EdStatsDataPivotP3E1.shape
# Out:
# (216, 12)

# %% [markdown]
# # Etape 2
# ## Choisissez un indicateur (celui que vous voulez) et calculez ses statistiques descriptives basiques puis tracez sa distribution.

# %%
EdStatsDataPivotP3E1["IT.NET.USER.P2"].describe()
# Out:
# count    208.000000
# mean      20.817270
# std       16.806272
# min        0.000000
# 25%        5.976359
# 50%       17.591902
# 75%       32.051111
# max       68.874359
# Name: IT.NET.USER.P2, dtype: float64

# %% [markdown]
# ### On prend le IT.NET.USER.P2 qui correspond au pourcentage de la population qui utilisent internet

# %%
sns.displot(data = EdStatsDataPivotP3E1, x = "IT.NET.USER.P2")
plt.title("Distribution de l'indicateur : IT.NET.USER.P2")
plt.xlabel("IT.NET.USER.P2")
plt.ylabel("Fréquence")
plt.show()

# %% [markdown]
# ## Réécrivez le code de l’instruction ci-dessus dans une fonction, et appliquezla à l’ensemble des autres indicateurs via une boucle for.

# %%
indicateurs_utiles2 = ["SP.POP.GROW", "SE.SEC.DURS.LO", "SE.SEC.DURS.UP", "SE.SEC.AGES", "SE.PRM.AGES", "SE.PRM.DURS", "UIS.THDUR.0", "UIS.THAGE.0", "IT.NET.USER.P2", "UIS.THAGE.3.A.GPV", "SE.SEC.DURS", "SP.SEC.UTOT.IN"]

for col in indicateurs_utiles2:
    print("Statistiques descriptives pour l'indicateur : ", col)
    print(EdStatsDataPivotP3E1[col].describe())
    print("\n")
    
    sns.displot(data = EdStatsDataPivotP3E1, x = col)
    plt.title(f"Distribution de l'indicateur : {col}")
    plt.xlabel(col)
    plt.ylabel("Fréquence")
    plt.show()
# Out:
# Statistiques descriptives pour l'indicateur :  SP.POP.GROW
# count    215.000000
# mean       1.731168
# std        1.214317
# min       -0.379458
# 25%        0.698688
# 50%        1.775489
# 75%        2.517564
# max        8.121829
# Name: SP.POP.GROW, dtype: float64
# Statistiques descriptives pour l'indicateur :  SE.SEC.DURS.LO
# count    208.000000
# mean       3.405537
# std        0.781011
# min        2.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        6.000000
# Name: SE.SEC.DURS.LO, dtype: float64
# Statistiques descriptives pour l'indicateur :  SE.SEC.DURS.UP
# count    208.000000
# mean       2.941039
# std        0.692575
# min        1.000000
# 25%        2.473404
# 50%        3.000000
# 75%        3.170213
# max        5.000000
# Name: SE.SEC.DURS.UP, dtype: float64
# Statistiques descriptives pour l'indicateur :  SE.SEC.AGES
# count    208.000000
# mean      11.806645
# std        0.861318
# min       10.000000
# ...

# %% [markdown]
# ## Interprétez la distribution pour chaque indicateur.

# %% [markdown]
# ### IT.NET.USER.P2 : taux d'utilisation d'internet : faible dans beaucoup de pays
# ### SP.POP.GROW : le taux de croissance de la population : centré autour de la moyenne avec peu de valeurs extreme mais avec deux pic qui peuvent laisser présager deux sous groupe (inferieur ou superieur a 2)
# ### SE.SEC.DURS.LO : la durée théorique du collège :  plate avec deux pics autour de la moyenne peuvent laisser présager deux sous groupe (inferieur ou superieur a 3,5 ans)
# ### SE.SEC.DURS.UP : la durée théorique du lycée : comporte trois pics dont le central qui fait le double des autres, situé au niveau de la moyenne (et de la mediane) laisse présager un groupe fortement majoritaire (pays à 3 ans de moyenne) suivie de deux sous groupes (2 et 4)
# ### SE.SEC.AGES : l'age d'entrée en études secondaires à un pic majeur autour de 12 ans (beaucoup de pays) et 3 sous groupes 10, 11 et 13
# ### SE.PRM.DURS : la durée théorique des etudes primaires à un pic majeur a 6 ans (beaucoup de pays) et deux pics moindres à 5 et 7 ans
# ### UIS.THDUR.0 : la durée théorique de l'education pré école primaire à tres peu de pays an dessous des deux ans,  beaucoup de pays autour des 2 et 3 ans et un dernier pic, moindre juste en dessous des 4 ans
# ### UIS.THAGE.0 : l'age d'entrée théorique pour l'education pré école primaire à un pic majeurs autour de 3 ans (beaucoup de pays) le reste est presque symetrique centré sur le 4
# ### UIS.THAGE.3.A.GPV : l'age d'entrée théorique au lycée : pic majeur autour de 15 ans, deux pics secondaire pour 14 et 16 ans
# ### SE.SEC.DURS : durée théorique de l'éducation secondaire : pic majeur 6 ans, secondaire 7 ans , puis 5 ans et pour finir 8 ans  (4 sous groupe de pays de taille décroissante)
# ### SP.SEC.UTOT.IN : Population en age d'aller au lycée : Beaucoup de pays ont une valeur tres faible, donc population jeune ou  vieille
# ### SE.PRM.AGES : age officiel d'entrée en primaire : Grande majorité à 6 ans avec un pic secondaire à 7 et un derniers a 5 ans

# %%
EdStatsDataNewA.loc[EdStatsDataNewA["Indicator Code"] == "SE.PRM.AGES", "Indicator Name"]
# Out:
# 93309     Official entrance age to primary education (years)
# 96974     Official entrance age to primary education (years)
# 100639    Official entrance age to primary education (years)
# 104304    Official entrance age to primary education (years)
# 107969    Official entrance age to primary education (years)
#                                  ...
# 870289    Official entrance age to primary education (years)
# 873954    Official entrance age to primary education (years)
# 877619    Official entrance age to primary education (years)
# 881284    Official entrance age to primary education (years)
# 884949    Official entrance age to primary education (years)
# Name: Indicator Name, Length: 216, dtype: object

# %% [markdown]
# ## Proposez une méthode quantitative, sur la base des indicateurs, pour sélectionner des pays et répondre à la demande de Mark
# ### Un exemple de méthode quantitative serait de prendre le top 5 de pays par indicateur, et de calculer le nombre de pays communs entre plusieurs top 5. Vous pouvez également envisager des moyennes pondérées des différents indicateurs (en fixant les poids selon votre compréhension métier de l’importance des indicateurs).

# %%
top5_IT_NET_USER_P2 = EdStatsDataPivotP3E1.sort_values('IT.NET.USER.P2', ascending = False)
top5ITNETUSERP2.head()
# Out:
# Indicator Code  IT.NET.USER.P2  SE.PRM.AGES  SE.PRM.DURS  SE.SEC.AGES  \
# Country Name
# Liechtenstein        68.874359     6.382979     5.000000    11.382979
# Monaco               65.083306     6.000000     5.000000    11.000000
# Bermuda              61.165283     5.000000     6.574468    11.595745
# Iceland              59.601732     6.446809     6.553191    13.000000
# Norway               57.951514     6.574468     6.425532    13.000000
#
# Indicator Code  SE.SEC.DURS  SE.SEC.DURS.LO  SE.SEC.DURS.UP  SP.POP.GROW  \
# Country Name
# Liechtenstein      7.000000             4.0        3.000000     1.266998
# Monaco             7.000000             4.0        3.000000     1.064269
# Bermuda            5.808511             3.0        2.808511     0.408086
# Iceland            7.000000             3.0        4.000000     1.057177
# Norway             6.000000             3.0        3.000000     0.654242
#
# Indicator Code  SP.SEC.UTOT.IN  UIS.THAGE.0  UIS.THAGE.3.A.GPV  UIS.THDUR.0
# ...

# %%
top5_SE_PRM_AGES = EdStatsDataPivotP3E1.sort_values('SE.PRM.AGES')
top5_SE_PRM_AGES.head()
# Out:
# Indicator Code          IT.NET.USER.P2  SE.PRM.AGES  SE.PRM.DURS  SE.SEC.AGES  \
# Country Name
# Gibraltar                    38.137710     4.425532     7.148936    11.595745
# Antigua and Barbuda          29.976907     5.000000     7.000000    12.000000
# Bermuda                      61.165283     5.000000     6.574468    11.595745
# Bahamas, The                 31.306882     5.000000     6.000000    11.000000
# British Virgin Islands             NaN     5.000000     7.000000    12.000000
#
# Indicator Code          SE.SEC.DURS  SE.SEC.DURS.LO  SE.SEC.DURS.UP  \
# Country Name
# Gibraltar                  5.191489        3.191489        2.000000
# Antigua and Barbuda        5.000000        3.000000        2.000000
# Bermuda                    5.808511        3.000000        2.808511
# Bahamas, The               6.000000        3.000000        3.000000
# British Virgin Islands     5.000000        3.000000        2.000000
#
# ...

# %%
top5_SE_PRM_DURS = EdStatsDataPivotP3E1.sort_values('SE.PRM.DURS')
top5_SE_PRM_DURS.head()
# Out:
# Indicator Code      IT.NET.USER.P2  SE.PRM.AGES  SE.PRM.DURS  SE.SEC.AGES  \
# Country Name
# Armenia                  15.261454     6.872340     3.191489    10.085106
# Russian Federation       22.724911     7.000000     3.276596    10.276596
# Ukraine                  13.242740     6.702128     3.297872    10.000000
# Azerbaijan               24.457607     6.553191     3.446809    10.000000
# Kyrgyz Republic          12.726902     7.000000     3.446809    10.446809
#
# Indicator Code      SE.SEC.DURS  SE.SEC.DURS.LO  SE.SEC.DURS.UP  SP.POP.GROW  \
# Country Name
# Armenia                7.021277        4.914894        2.106383     0.365706
# Russian Federation     7.000000        5.000000        2.000000     0.228174
# Ukraine                7.000000        5.000000        2.000000    -0.080803
# Azerbaijan             7.000000        5.000000        2.000000     1.393200
# Kyrgyz Republic        7.000000        5.000000        2.000000     1.579857
#
# ...

# %%
top5_SE_SEC_AGES = EdStatsDataPivotP3E1.sort_values('SE.SEC.AGES')
top5_SE_SEC_AGES.head()
# Out:
# Indicator Code      IT.NET.USER.P2  SE.PRM.AGES  SE.PRM.DURS  SE.SEC.AGES  \
# Country Name
# Azerbaijan               24.457607     6.553191     3.446809         10.0
# Austria                  43.242725     6.000000     4.000000         10.0
# Germany                  46.003307     6.000000     4.000000         10.0
# West Bank and Gaza       25.972853     6.000000     4.000000         10.0
# Ukraine                  13.242740     6.702128     3.297872         10.0
#
# Indicator Code      SE.SEC.DURS  SE.SEC.DURS.LO  SE.SEC.DURS.UP  SP.POP.GROW  \
# Country Name
# Azerbaijan                  7.0             5.0             2.0     1.393200
# Austria                     8.0             4.0             4.0     0.344126
# Germany                     9.0             6.0             3.0     0.126125
# West Bank and Gaza          8.0             6.0             2.0     3.204845
# Ukraine                     7.0             5.0             2.0    -0.080803
#
# ...

# %%
top5_SE_SEC_DURS = EdStatsDataPivotP3E1.sort_values('SE.SEC.DURS')
top5_SE_SEC_DURS.head()
# Out:
# Indicator Code       IT.NET.USER.P2  SE.PRM.AGES  SE.PRM.DURS  SE.SEC.AGES  \
# Country Name
# Philippines               14.631854     6.574468          6.0    12.595745
# Antigua and Barbuda       29.976907     5.000000          7.0    12.000000
# Botswana                   5.456909     6.361702          7.0    13.361702
# Aruba                     42.330053     6.000000          6.0    12.000000
# Dominica                  31.353321     5.000000          7.0    12.000000
#
# Indicator Code       SE.SEC.DURS  SE.SEC.DURS.LO  SE.SEC.DURS.UP  SP.POP.GROW  \
# Country Name
# Philippines                  4.0        3.000000        1.000000     2.316112
# Antigua and Barbuda          5.0        3.000000        2.000000     0.907370
# Botswana                     5.0        2.468085        2.531915     2.566181
# Aruba                        5.0        2.000000        3.000000     1.232726
# Dominica                     5.0        3.000000        2.000000     0.098589
#
# ...

# %%
top5_SE_SEC_DURS_LO = EdStatsDataPivotP3E1.sort_values('SE.SEC.DURS.LO')
top5_SE_SEC_DURS_LO.head()
# Out:
# Indicator Code    IT.NET.USER.P2  SE.PRM.AGES  SE.PRM.DURS  SE.SEC.AGES  \
# Country Name
# Aruba                  42.330053          6.0     6.000000    12.000000
# Bolivia                13.163707          6.0     6.042553    12.000000
# Congo, Dem. Rep.        0.961685          6.0     6.000000    12.000000
# Chile                  26.988312          6.0     6.042553    12.042553
# Curacao                      NaN          6.0     6.000000    12.000000
#
# Indicator Code    SE.SEC.DURS  SE.SEC.DURS.LO  SE.SEC.DURS.UP  SP.POP.GROW  \
# Country Name
# Aruba                5.000000             2.0        3.000000     1.232726
# Bolivia              6.000000             2.0        4.000000     1.921196
# Congo, Dem. Rep.     6.000000             2.0        4.000000     2.974038
# Chile                5.957447             2.0        3.957447     1.376496
# Curacao              6.000000             2.0        4.000000     0.404099
#
# ...

# %%
top5_SE_SEC_DURS_UP = EdStatsDataPivotP3E1.sort_values('SE.SEC.DURS.UP')
top5_SE_SEC_DURS_UP.head()
# Out:
# Indicator Code          IT.NET.USER.P2  SE.PRM.AGES  SE.PRM.DURS  SE.SEC.AGES  \
# Country Name
# Philippines                  14.631854     6.574468     6.000000    12.595745
# American Samoa                0.000000     6.000000     6.944444    13.636364
# Azerbaijan                   24.457607     6.553191     3.446809    10.000000
# Antigua and Barbuda          29.976907     5.000000     7.000000    12.000000
# British Virgin Islands             NaN     5.000000     7.000000    12.000000
#
# Indicator Code          SE.SEC.DURS  SE.SEC.DURS.LO  SE.SEC.DURS.UP  \
# Country Name
# Philippines                     4.0        3.000000             1.0
# American Samoa                  NaN        2.363636             2.0
# Azerbaijan                      7.0        5.000000             2.0
# Antigua and Barbuda             5.0        3.000000             2.0
# British Virgin Islands          5.0        3.000000             2.0
#
# ...

# %%
top5_SP_POP_GROW = EdStatsDataPivotP3E1.sort_values('SP.POP.GROW', ascending = False)
top5_SP_POP_GROW.head()
# Out:
# Indicator Code        IT.NET.USER.P2  SE.PRM.AGES  SE.PRM.DURS  SE.SEC.AGES  \
# Country Name
# United Arab Emirates       44.954249          6.0     5.717391    11.717391
# Qatar                      36.190109          6.0     6.000000    12.000000
# Kuwait                     30.885168          6.0     4.239130    10.239130
# Bahrain                    37.931310          6.0     6.000000    12.000000
# Cayman Islands             48.165581          5.0     6.000000    11.000000
#
# Indicator Code        SE.SEC.DURS  SE.SEC.DURS.LO  SE.SEC.DURS.UP  \
# Country Name
# United Arab Emirates     6.282609        3.282609         3.00000
# Qatar                    6.000000        3.000000         3.00000
# Kuwait                   7.760870        4.000000         3.76087
# Bahrain                  5.782609        2.782609         3.00000
# Cayman Islands           6.000000        3.000000         3.00000
#
# Indicator Code        SP.POP.GROW  SP.SEC.UTOT.IN  UIS.THAGE.0  \
# Country Name
# ...

# %%
top5_SP_SEC_UTOT_IN = EdStatsDataPivotP3E1.sort_values('SP.SEC.UTOT.IN', ascending = False)
top5_SP_SEC_UTOT_IN.head()
# Out:
# Indicator Code  IT.NET.USER.P2  SE.PRM.AGES  SE.PRM.DURS  SE.SEC.AGES  \
# Country Name
# India                 5.668691     6.000000     5.000000         11.0
# China                16.883452     6.702128     5.297872         12.0
# United States        47.021176     6.000000     6.000000         12.0
# Indonesia             6.549042     7.000000     6.000000         13.0
# Brazil               20.940767     6.914894     4.085106         11.0
#
# Indicator Code  SE.SEC.DURS  SE.SEC.DURS.LO  SE.SEC.DURS.UP  SP.POP.GROW  \
# Country Name
# India              7.000000        3.000000        4.000000     1.902531
# China              5.680851        2.851064        2.829787     1.168596
# United States      6.000000        3.000000        3.000000     0.992412
# Indonesia          6.000000        3.000000        3.000000     1.804788
# Brazil             7.000000        4.000000        3.000000     1.710567
#
# Indicator Code  SP.SEC.UTOT.IN  UIS.THAGE.0  UIS.THAGE.3.A.GPV  UIS.THDUR.0
# ...

# %%
top5_UIS_THAGE_0 = EdStatsDataPivotP3E1.sort_values('UIS.THAGE.0')
top5_UIS_THAGE_0.head()
# Out:
# Indicator Code  IT.NET.USER.P2  SE.PRM.AGES  SE.PRM.DURS  SE.SEC.AGES  \
# Country Name
# Cyprus               31.026812          6.0          6.0         12.0
# Israel               32.019261          6.0          6.0         12.0
# France               38.614994          6.0          5.0         11.0
# New Zealand          51.106674          5.0          6.0         11.0
# St. Lucia            23.309776          5.0          7.0         12.0
#
# Indicator Code  SE.SEC.DURS  SE.SEC.DURS.LO  SE.SEC.DURS.UP  SP.POP.GROW  \
# Country Name
# Cyprus                  6.0             3.0             3.0     1.399573
# Israel                  6.0             3.0             3.0     2.316689
# France                  7.0             4.0             3.0     0.550804
# New Zealand             7.0             4.0             3.0     1.038480
# St. Lucia               5.0             3.0             2.0     1.169316
#
# Indicator Code  SP.SEC.UTOT.IN  UIS.THAGE.0  UIS.THAGE.3.A.GPV  UIS.THDUR.0
# ...

# %%
top5_UIS_THAGE_3_A_GPV = EdStatsDataPivotP3E1.sort_values('UIS.THAGE.3.A.GPV')
top5_UIS_THAGE_3_A_GPV.head()
# Out:
# Indicator Code  IT.NET.USER.P2  SE.PRM.AGES  SE.PRM.DURS  SE.SEC.AGES  \
# Country Name
# Gibraltar            38.137710     4.425532     7.148936    11.595745
# Pakistan              5.851741     5.000000     5.000000    10.000000
# Samoa                 7.471958     5.000000     6.042553    11.042553
# Nepal                 3.678443     5.702128     4.617021    10.319149
# Bermuda              61.165283     5.000000     6.574468    11.595745
#
# Indicator Code  SE.SEC.DURS  SE.SEC.DURS.LO  SE.SEC.DURS.UP  SP.POP.GROW  \
# Country Name
# Gibraltar          5.191489        3.191489        2.000000     0.426430
# Pakistan           7.000000        3.000000        4.000000     2.614367
# Samoa              6.957447        2.021277        4.936170     0.698521
# Nepal              6.191489        2.893617        3.297872     1.918877
# Bermuda            5.808511        3.000000        2.808511     0.408086
#
# Indicator Code  SP.SEC.UTOT.IN  UIS.THAGE.0  UIS.THAGE.3.A.GPV  UIS.THDUR.0
# ...

# %%
top5_UIS_THDUR_0 = EdStatsDataPivotP3E1.sort_values('UIS.THDUR.0')
top5_UIS_THDUR_0.head()
# Out:
# Indicator Code      IT.NET.USER.P2  SE.PRM.AGES  SE.PRM.DURS  SE.SEC.AGES  \
# Country Name
# Australia                46.675617     5.531915     6.468085    12.000000
# Bermuda                  61.165283     5.000000     6.574468    11.595745
# Gibraltar                38.137710     4.425532     7.148936    11.595745
# Guam                     35.249497     6.000000     8.000000          NaN
# Iran, Islamic Rep.       12.485650     6.000000     5.108696    11.108696
#
# Indicator Code      SE.SEC.DURS  SE.SEC.DURS.LO  SE.SEC.DURS.UP  SP.POP.GROW  \
# Country Name
# Australia              6.000000        3.510638        2.489362     1.439897
# Bermuda                5.808511        3.000000        2.808511     0.408086
# Gibraltar              5.191489        3.191489        2.000000     0.426430
# Guam                        NaN             NaN             NaN     1.459372
# Iran, Islamic Rep.     6.760870        2.934783        3.826087     2.258944
#
# ...

# %% [markdown]
# ## En observant les différent top 5 on selectionne les pays qui apparaissent plusieurs fois
# ### 4 fois Bermuda,
# ### 3 fois Gibraltar, Antigua and Barbuda, Azerbaijan
# ### 2 fois Ukraine, Philippines et Aruba
